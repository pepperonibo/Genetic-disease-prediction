# %% [markdown]
# # 多遗传疾病非端到端多分类模型

# %%
import os
import json
from sklearn.model_selection  import cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from deepface import DeepFace
from sklearn.metrics import classification_report

# %% [markdown]
# 设置数据源路径以及保存模型位置

# %%
NORMALIZED_IMG_DIR = './dataset/'
clf_model_name = 'mutil-disease.pkl'

# %% [markdown]
# 读取所有遗传病类型

# %%
class_list = os.listdir(NORMALIZED_IMG_DIR)

# %% [markdown]
# 引入FaceNet

# %%
model = DeepFace.build_model('Facenet')

# %% [markdown]
# 使用FaceNet获取人脸embedding特征向量

# %%
embeddings = {}

# %%
for class_name in class_list:
#     embeddings[class_name] = DeepFace.represent(os.listdir(os.path.join(NORMALIZED_IMG_DIR, class_name)), model_name = 'Facenet', enforce_detection=False)
    embeddings[class_name] = []
    for file_name in os.listdir(os.path.join(NORMALIZED_IMG_DIR, class_name)):
        print(f"getting {file_name}'s embedding")
        embeddings[class_name].append(
            DeepFace.represent(os.path.join(NORMALIZED_IMG_DIR, class_name, file_name), model_name = 'Facenet', model=model, enforce_detection=False)
        )
# Out:
# getting 0.jpg's embedding
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001CF017DC310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001CF01997550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# getting 1.jpg's embedding
# getting 10.jpg's embedding
# getting 11.jpg's embedding
# getting 12.jpg's embedding
# getting 13.jpg's embedding
# getting 14.jpg's embedding
# getting 15.jpg's embedding
# getting 16.jpg's embedding
# getting 17.jpg's embedding
# getting 18.jpg's embedding
# getting 19.jpg's embedding
# getting 2.jpg's embedding
# getting 20.jpg's embedding
# getting 21.jpg's embedding
# getting 23.jpg's embedding
# getting 3.jpg's embedding
# getting 4.jpg's embedding
# getting 5.jpg's embedding
# getting 6.jpg's embedding
# getting 7.jpg's embedding
# getting 8.jpg's embedding
# getting 9.jpg's embedding
# getting 1.jpg's embedding
# getting 10.jpg's embedding
# getting 101.jpg's embedding
# getting 102.jpg's embedding
# getting 103.jpg's embedding
# getting 104.jpg's embedding
# getting 105.jpg's embedding
# getting 106.jpg's embedding
# getting 107.jpg's embedding
# getting 108.jpg's embedding
# getting 109.jpg's embedding
# getting 11.jpg's embedding
# getting 110.jpg's embedding
# getting 111.jpg's embedding
# getting 112.jpg's embedding
# getting 114.jpg's embedding
# getting 115.jpg's embedding
# getting 116.jpg's embedding
# getting 117.jpg's embedding
# getting 118.jpg's embedding
# getting 119.jpg's embedding
# getting 12.jpg's embedding
# getting 120.jpg's embedding
# getting 121.jpg's embedding
# getting 122.jpg's embedding
# getting 123.jpg's embedding
# getting 124.jpg's embedding
# getting 125.jpg's embedding
# getting 126.jpg's embedding
# getting 127.jpg's embedding
# getting 128.jpg's embedding
# getting 129.jpg's embedding
# getting 13.jpg's embedding
# getting 130.jpg's embedding
# getting 132.jpg's embedding
# getting 134.jpg's embedding
# getting 135.jpg's embedding
# getting 136.jpg's embedding
# getting 138.jpg's embedding
# getting 139.jpg's embedding
# getting 14.jpg's embedding
# getting 140.jpg's embedding
# getting 141.jpg's embedding
# getting 142.jpg's embedding
# getting 144.jpg's embedding
# getting 145.jpg's embedding
# getting 146.jpg's embedding
# getting 147.jpg's embedding
# getting 149.jpg's embedding
# getting 72.jpg's embedding
# getting 73.jpg's embedding
# getting 74.jpg's embedding
# getting 75.jpg's embedding
# getting 76.jpg's embedding
# getting 8.jpg's embedding
# getting 80.jpg's embedding
# getting 81.jpg's embedding
# getting 82.jpg's embedding
# getting 83.jpg's embedding
# getting 84.jpg's embedding
# getting 86.jpg's embedding
# getting 88.jpg's embedding
# getting 89.jpg's embedding
# getting 90.jpg's embedding
# getting 91.jpg's embedding
# getting 93.jpg's embedding
# getting 94.jpg's embedding
# getting 95.jpg's embedding
# getting 96.jpg's embedding
# getting 99.jpg's embedding
# getting 1013.png's embedding
# getting 1014.png's embedding
# getting 1034.png's embedding
# getting 1037.png's embedding
# getting 1039.png's embedding
# getting 106.png's embedding
# getting 1078.png's embedding
# getting 1088.png's embedding
# getting 1089.png's embedding
# getting 1100.png's embedding
# getting 1108.png's embedding
# getting 1109.png's embedding
# getting 1113.png's embedding
# getting 1126.png's embedding
# getting 1140.png's embedding
# getting 1160.png's embedding
# getting 1184.png's embedding
# getting 1191.png's embedding
# getting 1202.png's embedding
# getting 1209.png's embedding
# getting 1233.png's embedding
# getting 1241.png's embedding
# getting 1251.png's embedding
# getting 1252.png's embedding
# getting 1254.png's embedding
# getting 1276.png's embedding
# getting 1283.png's embedding
# getting 1303.png's embedding
# getting 1316.png's embedding
# getting 132.png's embedding
# getting 1321.png's embedding
# getting 1330.png's embedding
# getting 1338.png's embedding
# getting 1340.png's embedding
# getting 1341.png's embedding
# getting 1343.png's embedding
# getting 1348.png's embedding
# getting 1360.png's embedding
# getting 1372.png's embedding
# getting 1374.png's embedding
# getting 1431.png's embedding
# getting 1448.png's embedding
# getting 1468.png's embedding
# getting 1478.png's embedding
# getting 1490.png's embedding
# getting 1491.png's embedding
# getting 1496.png's embedding
# getting 1522.png's embedding
# getting 155.png's embedding
# getting 1552.png's embedding
# getting 1555.png's embedding
# getting 1569.png's embedding
# getting 1573.png's embedding
# getting 1575.png's embedding
# getting 1597.png's embedding
# getting 1615.png's embedding
# getting 1636.png's embedding
# getting 1637.png's embedding
# getting 1638.png's embedding
# getting 1674.png's embedding
# getting 168.png's embedding
# getting 1688.png's embedding
# getting 1690.png's embedding
# getting 170.png's embedding
# getting 171.png's embedding
# getting 1714.png's embedding
# getting 1727.png's embedding
# getting 1739.png's embedding
# getting 1742.png's embedding
# getting 1749.png's embedding
# getting 1752.png's embedding
# getting 1761.png's embedding
# getting 1764.png's embedding
# getting 1765.png's embedding
# getting 1789.png's embedding
# getting 181.png's embedding
# getting 1824.png's embedding
# getting 1842.png's embedding
# getting 1848.png's embedding
# getting 1865.png's embedding
# getting 1869.png's embedding
# getting 1870.png's embedding
# getting 1878.png's embedding
# getting 1883.png's embedding
# getting 1885.png's embedding
# getting 190.png's embedding
# getting 1907.png's embedding
# getting 1916.png's embedding
# getting 1924.png's embedding
# getting 1929.png's embedding
# getting 1935.png's embedding
# getting 1937.png's embedding
# getting 1938.png's embedding
# getting 1970.png's embedding
# getting 1982.png's embedding
# getting 2031.png's embedding
# getting 2033.png's embedding
# getting 2046.png's embedding
# getting 2054.png's embedding
# getting 2058.png's embedding
# getting 2059.png's embedding
# getting 2092.png's embedding
# getting 2095.png's embedding
# getting 2108.png's embedding
# getting 2114.png's embedding
# getting 2118.png's embedding
# getting 213.png's embedding
# getting 2140.png's embedding
# getting 2152.png's embedding
# getting 2157.png's embedding
# getting 2194.png's embedding
# getting 2209.png's embedding
# getting 2214.png's embedding
# getting 2222.png's embedding
# getting 223.png's embedding
# getting 2246.png's embedding
# getting 2260.png's embedding
# getting 2264.png's embedding
# getting 2293.png's embedding
# getting 2320.png's embedding
# getting 2334.png's embedding
# getting 2335.png's embedding
# getting 2359.png's embedding
# getting 2373.png's embedding
# getting 2383.png's embedding
# getting 2394.png's embedding
# getting 242.png's embedding
# getting 2430.png's embedding
# getting 2461.png's embedding
# getting 2489.png's embedding
# getting 2490.png's embedding
# getting 25.png's embedding
# getting 2504.png's embedding
# getting 2529.png's embedding
# getting 2558.png's embedding
# getting 2596.png's embedding
# getting 2602.png's embedding
# getting 2612.png's embedding
# getting 2621.png's embedding
# getting 2644.png's embedding
# getting 2658.png's embedding
# getting 2661.png's embedding
# getting 2662.png's embedding
# getting 2688.png's embedding
# getting 2691.png's embedding
# getting 2722.png's embedding
# getting 2727.png's embedding
# getting 2743.png's embedding
# getting 2753.png's embedding
# getting 2754.png's embedding
# getting 2781.png's embedding
# getting 2809.png's embedding
# getting 2827.png's embedding
# getting 286.png's embedding
# getting 2865.png's embedding
# getting 2875.png's embedding
# getting 2892.png's embedding
# getting 2897.png's embedding
# getting 2899.png's embedding
# getting 2903.png's embedding
# getting 2906.png's embedding
# getting 2939.png's embedding
# getting 2967.png's embedding
# getting 2988.png's embedding
# getting 2999.png's embedding
# getting 3006.png's embedding
# getting 3024.png's embedding
# getting 3051.png's embedding
# getting 3058.png's embedding
# getting 3080.png's embedding
# getting 3085.png's embedding
# getting 3090.png's embedding
# getting 3095.png's embedding
# getting 3099.png's embedding
# getting 3118.png's embedding
# getting 3123.png's embedding
# getting 3137.png's embedding
# getting 3149.png's embedding
# getting 3162.png's embedding
# getting 319.png's embedding
# getting 3217.png's embedding
# getting 3236.png's embedding
# getting 3250.png's embedding
# getting 3273.png's embedding
# getting 328.png's embedding
# getting 3315.png's embedding
# getting 3347.png's embedding
# getting 3367.png's embedding
# getting 3393.png's embedding
# getting 3410.png's embedding
# getting 3426.png's embedding
# getting 3449.png's embedding
# getting 3454.png's embedding
# getting 346.png's embedding
# getting 347.png's embedding
# getting 3477.png's embedding
# getting 3481.png's embedding
# getting 3484.png's embedding
# getting 3536.png's embedding
# getting 3541.png's embedding
# getting 3565.png's embedding
# getting 3572.png's embedding
# getting 3579.png's embedding
# getting 3586.png's embedding
# getting 3588.png's embedding
# getting 3589.png's embedding
# getting 3593.png's embedding
# getting 3618.png's embedding
# getting 3624.png's embedding
# getting 3640.png's embedding
# getting 3672.png's embedding
# getting 3686.png's embedding
# getting 3687.png's embedding
# getting 369.png's embedding
# getting 3690.png's embedding
# getting 3720.png's embedding
# getting 3724.png's embedding
# getting 3728.png's embedding
# getting 3745.png's embedding
# getting 3759.png's embedding
# getting 376.png's embedding
# getting 3760.png's embedding
# getting 3769.png's embedding
# getting 378.png's embedding
# getting 3795.png's embedding
# getting 3814.png's embedding
# getting 3819.png's embedding
# getting 3824.png's embedding
# getting 384.png's embedding
# getting 3845.png's embedding
# getting 3848.png's embedding
# getting 3850.png's embedding
# getting 3852.png's embedding
# getting 3867.png's embedding
# getting 3875.png's embedding
# getting 390.png's embedding
# getting 391.png's embedding
# getting 3915.png's embedding
# getting 3933.png's embedding
# getting 3959.png's embedding
# getting 4016.png's embedding
# getting 4020.png's embedding
# getting 4021.png's embedding
# getting 4029.png's embedding
# getting 4040.png's embedding
# getting 4048.png's embedding
# getting 4049.png's embedding
# getting 4061.png's embedding
# getting 4080.png's embedding
# getting 4091.png's embedding
# getting 4110.png's embedding
# getting 4113.png's embedding
# getting 4157.png's embedding
# getting 4163.png's embedding
# getting 4172.png's embedding
# getting 4173.png's embedding
# getting 4202.png's embedding
# getting 4223.png's embedding
# getting 4231.png's embedding
# getting 4232.png's embedding
# getting 4233.png's embedding
# getting 4274.png's embedding
# getting 4277.png's embedding
# getting 4286.png's embedding
# getting 4290.png's embedding
# getting 4291.png's embedding
# getting 4323.png's embedding
# getting 4342.png's embedding
# getting 4359.png's embedding
# getting 4376.png's embedding
# getting 438.png's embedding
# getting 4383.png's embedding
# getting 4394.png's embedding
# getting 4423.png's embedding
# getting 4424.png's embedding
# getting 4429.png's embedding
# getting 4434.png's embedding
# getting 445.png's embedding
# getting 4455.png's embedding
# getting 446.png's embedding
# getting 4463.png's embedding
# getting 4469.png's embedding
# getting 4482.png's embedding
# getting 4485.png's embedding
# getting 4516.png's embedding
# getting 4524.png's embedding
# getting 454.png's embedding
# getting 4547.png's embedding
# getting 4581.png's embedding
# getting 4592.png's embedding
# getting 4597.png's embedding
# getting 4625.png's embedding
# getting 4631.png's embedding
# getting 4642.png's embedding
# getting 4647.png's embedding
# getting 4648.png's embedding
# getting 4650.png's embedding
# getting 4651.png's embedding
# getting 4669.png's embedding
# getting 4679.png's embedding
# getting 4689.png's embedding
# getting 4698.png's embedding
# getting 4703.png's embedding
# getting 4739.png's embedding
# getting 4749.png's embedding
# getting 4761.png's embedding
# getting 4776.png's embedding
# getting 4782.png's embedding
# getting 4795.png's embedding
# getting 4805.png's embedding
# getting 4817.png's embedding
# getting 4830.png's embedding
# getting 4834.png's embedding
# getting 4838.png's embedding
# getting 4847.png's embedding
# getting 4855.png's embedding
# getting 4859.png's embedding
# getting 4864.png's embedding
# getting 4886.png's embedding
# getting 4896.png's embedding
# getting 4899.png's embedding
# getting 4902.png's embedding
# getting 4913.png's embedding
# getting 4925.png's embedding
# getting 4932.png's embedding
# getting 4933.png's embedding
# getting 494.png's embedding
# getting 4940.png's embedding
# getting 4945.png's embedding
# getting 4948.png's embedding
# getting 4953.png's embedding
# getting 4954.png's embedding
# getting 4986.png's embedding
# getting 5030.png's embedding
# getting 5032.png's embedding

# %% [markdown]
# 构造训练集和测试集

# %%
X = []
Y = []
for key, value in embeddings.items():
    X = X + value
    Y = Y + [key] * len(value)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.15)

# %% [markdown]
# 使用KNN作为分类器，使用网格搜索搜索最优参数

# %%
k_range = range(1, 10)
best_k = -1
best_score = -1
#循环，取k=1到k=31，查看误差效果 
for k in k_range:
    knn = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance'
    )
    #cv参数决定数据集划分比例，这里是按照5:1划分训练集和测试集
    score = cross_val_score(knn, Xtrain, Ytrain, cv=8, scoring='accuracy').mean()
    if score > best_score:
        best_score = score
        best_k = k
    print(f'knn with {k} neightbors: {score}')
print(f'best: acc: {best_score} k: {best_k}')
# Out:
# knn with 1 neightbors: 0.7228002070393376
# knn with 2 neightbors: 0.7228002070393376
# knn with 3 neightbors: 0.7353002070393375
# knn with 4 neightbors: 0.7388198757763975
# knn with 5 neightbors: 0.7477743271221532
# knn with 6 neightbors: 0.7406573498964804
# knn with 7 neightbors: 0.7442287784679089
# knn with 8 neightbors: 0.7442805383022775
# knn with 9 neightbors: 0.7388716356107661
# best: acc: 0.7477743271221532 k: 5

# %% [markdown]
# 使用最优参数训练KNN

# %%
knn = KNeighborsClassifier(n_neighbors=best_k, weights='distance')
knn.fit(Xtrain, Ytrain)
# Out:
# KNeighborsClassifier(weights='distance')

# %% [markdown]
# 评估KNN

# %%
knn.score(Xtest, Ytest)
# Out:
# 0.6767676767676768

# %%
y_pred = knn.predict(Xtest)

# %%
print(classification_report(Ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Angelman       0.00      0.00      0.00         2
#        Apert       0.76      0.72      0.74        40
#    Fragile_X       0.60      0.35      0.44        17
#       normal       0.63      0.80      0.70        40
#
#     accuracy                           0.68        99
#    macro avg       0.50      0.47      0.47        99
# weighted avg       0.66      0.68      0.66        99

# %%
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
print('accuracy:{}'.format(accuracy_score(Ytest, y_pred)))
print('precision:{}'.format(precision_score(Ytest, y_pred, average='micro')))
print('recall:{}'.format(recall_score(Ytest, y_pred,average='micro')))
print('f1-score:{}'.format(f1_score(Ytest, y_pred,average='micro')))
# Out:
# accuracy:0.6767676767676768
# precision:0.6767676767676768
# recall:0.6767676767676768
# f1-score:0.6767676767676768

# %% [markdown]
# 发现主要是一类疾病预测效果差，删去后重新训练模型，评估模型
# 发现效果有明显提升

# %%
del embeddings['Fragile_X']

# %%
X = []
Y = []
for key, value in embeddings.items():
    X = X + value
    Y = Y + [key] * len(value)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1)

# %%
knn = KNeighborsClassifier(n_neighbors=2, weights='distance')
knn.fit(Xtrain, Ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=2, weights='distance')

# %%
knn.score(Xtest, Ytest)
# Out:
# 0.8947368421052632

# %%
y_pred = knn.predict(Xtest)

# %%
print(classification_report(Ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Angelman       0.00      0.00      0.00         0
#        Apert       0.90      0.86      0.88        21
#       normal       0.92      0.92      0.92        36
#
#     accuracy                           0.89        57
#    macro avg       0.61      0.59      0.60        57
# weighted avg       0.91      0.89      0.90        57

# %%
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
print('accuracy:{}'.format(accuracy_score(Ytest, y_pred)))
print('precision:{}'.format(precision_score(Ytest, y_pred, average='micro')))
print('recall:{}'.format(recall_score(Ytest, y_pred,average='micro')))
print('f1-score:{}'.format(f1_score(Ytest, y_pred,average='micro')))
# Out:
# accuracy:0.8947368421052632
# precision:0.8947368421052632
# recall:0.8947368421052632
# f1-score:0.8947368421052632

# %%
print(classification_report(Ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     angelman       1.00      0.20      0.33         5
#        apert       0.77      0.74      0.76        46
#       normal       0.92      0.95      0.93       194
#
#     accuracy                           0.89       245
#    macro avg       0.90      0.63      0.67       245
# weighted avg       0.89      0.89      0.89       245
